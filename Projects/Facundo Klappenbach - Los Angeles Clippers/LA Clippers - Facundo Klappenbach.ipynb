# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.optimize import curve_fit

# %% [markdown]
# # LA Clippers Business Insights & Analytics

# %%
# Load the the data from excel file
df_Clippers = pd.read_excel('LA Clippers Data Challenge F&B Dataset.xlsx')

# %%
df_Clippers.head()
# Out:
#    OrderID OrderStatus  CustomerID     ArrivalDatetime   DepartureDatetime  \
# 0     1159        paid        1006 2023-03-23 00:13:18 2023-03-23 00:15:06
# 1     1159        paid        1006 2023-03-23 00:13:18 2023-03-23 00:15:06
# 2     1160        paid        1001 2023-03-23 00:15:24 2023-03-23 00:17:22
# 3     1160        paid        1001 2023-03-23 00:15:24 2023-03-23 00:17:22
# 4     1160        paid        1001 2023-03-23 00:15:24 2023-03-23 00:17:22
#
#    GroupSize     ProductID             ProductName  ProductQuantity  \
# 0          1  4.453241e+13  Aquafina- 20 oz bottle              1.0
# 1          1  4.453244e+13         Pepperoni Pizza              1.0
# 2          2  4.453244e+13    Starry- 20 oz bottle              1.0
# 3          2  4.453244e+13          Pink's Hot Dog              2.0
# 4          2  4.453244e+13        Sour Patch Candy              1.0
#
#    ProductFullPrice PaymentStatus  OrderTotalQuantity EmptyOrder     Category  \
# 0              7.15       success                   2         No  Non-alcohol
# 1             18.15       success                   2         No         Food
# 2              7.15       success                   4         No  Non-alcohol
# 3             18.70       success                   4         No         Food
# 4              6.05       success                   4         No         Food
#
#             SubCategory
# 0                 Water
# 1              Hot food
# 2  Non-alcohol Beverage
# 3              Hot food
# 4                 Snack

# %%
# Check the data types of the columns
df_Clippers.dtypes
# Out:
# OrderID                        int64
# OrderStatus                   object
# CustomerID                     int64
# ArrivalDatetime       datetime64[ns]
# DepartureDatetime     datetime64[ns]
# GroupSize                      int64
# ProductID                    float64
# ProductName                   object
# ProductQuantity              float64
# ProductFullPrice             float64
# PaymentStatus                 object
# OrderTotalQuantity             int64
# EmptyOrder                    object
# Category                      object
# SubCategory                   object
# dtype: object

# %%
df_Clippers.describe()
# Out:
#             OrderID    CustomerID                ArrivalDatetime  \
# count  65025.000000  65025.000000                          65025
# mean   17931.706344  16208.241753  2023-06-19 10:16:46.851042048
# min     1159.000000      9.000000            2023-03-23 00:08:03
# 25%     9499.000000   8551.000000            2023-05-11 00:21:19
# 50%    17866.000000  16164.000000            2023-06-10 02:51:35
# 75%    26054.000000  23691.000000            2023-08-12 00:39:00
# max    35455.000000  31969.000000            2023-09-04 05:16:01
# std     9818.958865   8876.491951                            NaN
#
#                    DepartureDatetime     GroupSize     ProductID  \
# count                          65025  65025.000000  6.369500e+04
# mean   2023-06-19 10:47:01.272941312      1.629727  4.453403e+13
# min              2023-03-23 00:15:06      0.000000  4.453240e+13
# 25%              2023-05-11 00:23:52      1.000000  4.453241e+13
# 50%              2023-06-10 03:16:06      2.000000  4.453243e+13
# 75%              2023-08-12 00:43:00      2.000000  4.453244e+13
# max              2023-09-05 03:38:26      9.000000  4.455953e+13
# std                              NaN      0.775624  6.112837e+09
#
#        ProductQuantity  ProductFullPrice  OrderTotalQuantity
# count     63695.000000      63695.000000        65025.000000
# mean          1.169275         14.938188            2.962537
# min           1.000000          5.500000            0.000000
# 25%           1.000000          7.150000            2.000000
# 50%           1.000000         14.300000            3.000000
# 75%           1.000000         19.810000            4.000000
# max          10.000000        203.500000           23.000000
# std           0.451269          9.976353            1.823947

# %%
# count number of nulls in each column
df_Clippers.isnull().sum()
# Out:
# OrderID                  0
# OrderStatus              0
# CustomerID               0
# ArrivalDatetime          0
# DepartureDatetime        0
# GroupSize                0
# ProductID             1330
# ProductName           1330
# ProductQuantity       1330
# ProductFullPrice      1330
# PaymentStatus            0
# OrderTotalQuantity       0
# EmptyOrder               0
# Category              1407
# SubCategory           1407
# dtype: int64

# %%
# select the rows with missing values
df_Clippers[df_Clippers.isnull().any(axis=1)]
# Out:
#        OrderID OrderStatus  CustomerID     ArrivalDatetime  \
# 81        1197        paid        1076 2023-03-23 01:15:21
# 501       1387        paid        1308 2023-03-23 02:13:15
# 553       1416        paid        1337 2023-03-23 02:20:15
# 618       1446        paid        1360 2023-03-23 02:25:48
# 659       1468        paid        1399 2023-03-23 02:35:18
# ...        ...         ...         ...                 ...
# 64991    35436        paid       31962 2023-09-04 05:07:26
# 64992    35437        paid       31969 2023-09-04 05:08:22
# 65009    35446        paid       31750 2023-09-04 02:54:11
# 65016    35451        paid       31800 2023-09-04 03:05:53
# 65024    35455        paid       31889 2023-09-04 03:29:00
#
#         DepartureDatetime  GroupSize ProductID ProductName  ProductQuantity  \
# 81    2023-03-23 01:16:50          2       NaN         NaN              NaN
# 501   2023-03-23 02:15:13          1       NaN         NaN              NaN
# 553   2023-03-23 02:22:10          1       NaN         NaN              NaN
# 618   2023-03-23 02:30:40          2       NaN         NaN              NaN
# 659   2023-03-23 02:36:52          1       NaN         NaN              NaN
# ...                   ...        ...       ...         ...              ...
# 64991 2023-09-04 05:09:17          1       NaN         NaN              NaN
# 64992 2023-09-04 05:09:36          2       NaN         NaN              NaN
# 65009 2023-09-04 05:36:09          1       NaN         NaN              NaN
# 65016 2023-09-04 05:36:43          1       NaN         NaN              NaN
# 65024 2023-09-05 03:38:26          5       NaN         NaN              NaN
#
#        ProductFullPrice PaymentStatus  OrderTotalQuantity EmptyOrder Category  \
# 81                  NaN       success                   0        Yes      NaN
# 501                 NaN       success                   0        Yes      NaN
# 553                 NaN       success                   0        Yes      NaN
# 618                 NaN       success                   0        Yes      NaN
# 659                 NaN       success                   0        Yes      NaN
# ...                 ...           ...                 ...        ...      ...
# 64991               NaN       success                   0        Yes      NaN
# 64992               NaN       success                   0        Yes      NaN
# 65009               NaN       success                   0        Yes      NaN
# 65016               NaN       success                   0        Yes      NaN
# 65024               NaN       success                   0        Yes      NaN
#
#       SubCategory
# 81            NaN
# 501           NaN
# 553           NaN
# 618           NaN
# 659           NaN
# ...           ...
# 64991         NaN
# 64992         NaN
# 65009         NaN
# 65016         NaN
# 65024         NaN
#
# [1407 rows x 15 columns]

# %%
df_Clippers[(df_Clippers['EmptyOrder'] == 'Yes')].shape[0]
# Out:
# 1330

# %%
# count number of rows with EmptyOrder = Yes and ProcutID = NaN 
df_Clippers[(df_Clippers['EmptyOrder'] == 'Yes') & (df_Clippers['ProductID'].isnull())].shape[0]
# Out:
# 1330

# %% [markdown]
# Here I identified that all the ProductID with null values are linked with EmptyOrder == Yes. I assume that this colum was created to identify missing values in the product category. To proceed with the analysis, I decided to separate this data from the one with values for simplicity. An important note is that is a good practice to save the information with NaN values so as to healp identifing why the EmptyOrders are created (inflo like OrderID, Timestamp, paid or not etc).

# %%
# separate the rows with EmptyOrder = Yes 
df_Clippers_EmptyOrder = df_Clippers[(df_Clippers['EmptyOrder'] == 'Yes')]
print(df_Clippers_EmptyOrder.shape[0])

# separate the rows with EmptyOrder = No
df_Clippers_complete = df_Clippers[(df_Clippers['EmptyOrder'] == 'No')]
print(df_Clippers_complete.shape[0])
# Out:
# 1330
# 63695

# %%
df_Clippers_complete.isnull().sum()
# Out:
# OrderID                0
# OrderStatus            0
# CustomerID             0
# ArrivalDatetime        0
# DepartureDatetime      0
# GroupSize              0
# ProductID              0
# ProductName            0
# ProductQuantity        0
# ProductFullPrice       0
# PaymentStatus          0
# OrderTotalQuantity     0
# EmptyOrder             0
# Category              77
# SubCategory           77
# dtype: int64

# %% [markdown]
# However, there are 77 products that were actually bought but are not assigned to a `Category` and `SubCategory`. Now I'll identified what product are those to see if I can complete them with the right value:

# %%
# select the rows with Empty order = No and missing values in the colum category
df_Clippers_complete['ProductName'][(df_Clippers_complete['EmptyOrder'] == 'No') & (df_Clippers_complete['Category'].isnull())].value_counts()
# Out:
# ProductName
# Ciroc Spritz Colada    77
# Name: count, dtype: int64

# %%
df_Clippers_complete.value_counts('Category')
# Out:
# Category
# Food           23715
# Alcohol        22445
# Non-alcohol    17458
# Name: count, dtype: int64

# %%
df_Clippers_complete[df_Clippers_complete['Category'] == 'Alcohol'].value_counts('SubCategory')
# Out:
# SubCategory
# Beer      11246
# Liquor    11199
# Name: count, dtype: int64

# %%
# select producnt name with subcategory = Liquor
df_Clippers_complete['ProductName'][df_Clippers_complete['SubCategory'] == 'Liquor'].value_counts()
# Out:
# ProductName
# White Claw Mango 24 oz can             2477
# White Claw Black Cherry 24 oz can      2184
# Cutwater Mango Margarita- 12 oz can    1693
# Cutwater Lime Margarita- 12 oz can     1351
# Ciroc Spritz Watermelon kiwi           1026
# Ciroc Spritz Pineapple Passion          750
# Ciroc spritz Citrus Sunset              678
# Cutwater Mai Tai- 12 oz can             419
# Cutwater Vodka Mule- 12 oz can          367
# Ciroc spritz Colada                     254
# Name: count, dtype: int64

# %% [markdown]
# Here I identify that the Ciroc Spritz Colada is actually classified as category 'Alcohol' and subcategory 'Liquor'

# %%
# fill the missing values in the column category with the value 'Alcohol', subcategory='Liquor' for the rows with product name = 'Ciroc spritz Colada' 
df_Clippers_complete.loc[df_Clippers_complete['ProductName'] == 'Ciroc Spritz Colada', 'Category'] = 'Alcohol'
df_Clippers_complete.loc[df_Clippers_complete['ProductName'] == 'Ciroc Spritz Colada', 'SubCategory'] = 'Liquor'

# %%
df_Clippers_complete['ProductName'][(df_Clippers_complete['EmptyOrder'] == 'No') & (df_Clippers_complete['Category'].isnull())].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df_Clippers_complete['ProductName'][(df_Clippers_complete['EmptyOrder'] == 'No') & (df_Clippers_complete['SubCategory'].isnull())].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
# count number of nulls in each column
df_Clippers_complete.isnull().sum()
# Out:
# OrderID               0
# OrderStatus           0
# CustomerID            0
# ArrivalDatetime       0
# DepartureDatetime     0
# GroupSize             0
# ProductID             0
# ProductName           0
# ProductQuantity       0
# ProductFullPrice      0
# PaymentStatus         0
# OrderTotalQuantity    0
# EmptyOrder            0
# Category              0
# SubCategory           0
# dtype: int64

# %% [markdown]
# Therefore, I can assume that the final data is clean and ready to use with the right values.

# %%
df_Clippers_complete.dtypes
# Out:
# OrderID                        int64
# OrderStatus                   object
# CustomerID                     int64
# ArrivalDatetime       datetime64[ns]
# DepartureDatetime     datetime64[ns]
# GroupSize                      int64
# ProductID                    float64
# ProductName                   object
# ProductQuantity              float64
# ProductFullPrice             float64
# PaymentStatus                 object
# OrderTotalQuantity             int64
# EmptyOrder                    object
# Category                      object
# SubCategory                   object
# dtype: object

# %%
# now I'll change ProductID type to int64 for better data management 
df_Clippers_complete['ProductID'] = df_Clippers_complete['ProductID'].astype('int64')

df_Clippers_complete.dtypes
# Out:
# C:\Users\Facundo\AppData\Local\Temp\ipykernel_4036\1365318354.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Clippers_complete['ProductID'] = df_Clippers_complete['ProductID'].astype('int64')
# OrderID                        int64
# OrderStatus                   object
# CustomerID                     int64
# ArrivalDatetime       datetime64[ns]
# DepartureDatetime     datetime64[ns]
# GroupSize                      int64
# ProductID                      int64
# ProductName                   object
# ProductQuantity              float64
# ProductFullPrice             float64
# PaymentStatus                 object
# OrderTotalQuantity             int64
# EmptyOrder                    object
# Category                      object
# SubCategory                   object
# dtype: object

# %% [markdown]
# Deliverable 1:

# %%
df_Clippers_complete[df_Clippers_complete.OrderID == 1160]
# Out:
#    OrderID OrderStatus  CustomerID     ArrivalDatetime   DepartureDatetime  \
# 2     1160        paid        1001 2023-03-23 00:15:24 2023-03-23 00:17:22
# 3     1160        paid        1001 2023-03-23 00:15:24 2023-03-23 00:17:22
# 4     1160        paid        1001 2023-03-23 00:15:24 2023-03-23 00:17:22
#
#    GroupSize       ProductID           ProductName  ProductQuantity  \
# 2          2  44532435157305  Starry- 20 oz bottle              1.0
# 3          2  44532436828473        Pink's Hot Dog              2.0
# 4          2  44532439187769      Sour Patch Candy              1.0
#
#    ProductFullPrice PaymentStatus  OrderTotalQuantity EmptyOrder     Category  \
# 2              7.15       success                   4         No  Non-alcohol
# 3             18.70       success                   4         No         Food
# 4              6.05       success                   4         No         Food
#
#             SubCategory
# 2  Non-alcohol Beverage
# 3              Hot food
# 4                 Snack

# %%
from pandasql import sqldf 
import pandas as pd 

pysqldf = lambda q: sqldf(q)
pysqldf("SELECT * FROM df_Clippers_complete")
# Out:
#        OrderID OrderStatus  CustomerID             ArrivalDatetime  \
# 0         1159        paid        1006  2023-03-23 00:13:18.000000
# 1         1159        paid        1006  2023-03-23 00:13:18.000000
# 2         1160        paid        1001  2023-03-23 00:15:24.000000
# 3         1160        paid        1001  2023-03-23 00:15:24.000000
# 4         1160        paid        1001  2023-03-23 00:15:24.000000
# ...        ...         ...         ...                         ...
# 63690    35453        paid       31597  2023-09-04 02:18:28.000000
# 63691    35453        paid       31597  2023-09-04 02:18:28.000000
# 63692    35453        paid       31597  2023-09-04 02:18:28.000000
# 63693    35453        paid       31597  2023-09-04 02:18:28.000000
# 63694    35454        paid       31677  2023-09-04 02:32:39.000000
#
#                 DepartureDatetime  GroupSize       ProductID  \
# 0      2023-03-23 00:15:06.000000          1  44532414808377
# 1      2023-03-23 00:15:06.000000          1  44532437975353
# 2      2023-03-23 00:17:22.000000          2  44532435157305
# 3      2023-03-23 00:17:22.000000          2  44532436828473
# 4      2023-03-23 00:17:22.000000          2  44532439187769
# ...                           ...        ...             ...
# 63690  2023-09-04 14:37:14.000000          4  44532435943737
# 63691  2023-09-04 14:37:14.000000          4  44532434469177
# 63692  2023-09-04 14:37:14.000000          4  44532435779897
# 63693  2023-09-04 14:37:14.000000          4  44532435878201
# 63694  2023-09-04 14:37:23.000000          4  44532434731321
#
#                           ProductName  ProductQuantity  ProductFullPrice  \
# 0              Aquafina- 20 oz bottle              1.0              7.15
# 1                     Pepperoni Pizza              1.0             18.15
# 2                Starry- 20 oz bottle              1.0              7.15
# 3                      Pink's Hot Dog              2.0             18.70
# 4                    Sour Patch Candy              1.0              6.05
# ...                               ...              ...               ...
# 63690    Ciroc Spritz Watermelon kiwi              1.0             19.25
# 63691          Lagunita IPA 24 oz can              1.0             20.91
# 63692  Ciroc Spritz Pineapple Passion              1.0             19.25
# 63693      Ciroc spritz Citrus Sunset              1.0             19.25
# 63694          24oz - Modelo Especial              1.0             19.50
#
#       PaymentStatus  OrderTotalQuantity EmptyOrder     Category  \
# 0           success                   2         No  Non-alcohol
# 1           success                   2         No         Food
# 2           success                   4         No  Non-alcohol
# 3           success                   4         No         Food
# 4           success                   4         No         Food
# ...             ...                 ...        ...          ...
# 63690       success                   4         No      Alcohol
# 63691       success                   4         No      Alcohol
# 63692       success                   4         No      Alcohol
# 63693       success                   4         No      Alcohol
# 63694       success                   1         No      Alcohol
#
#                 SubCategory
# 0                     Water
# 1                  Hot food
# 2      Non-alcohol Beverage
# 3                  Hot food
# 4                     Snack
# ...                     ...
# 63690                Liquor
# 63691                  Beer
# 63692                Liquor
# 63693                Liquor
# 63694                  Beer
#
# [63695 rows x 15 columns]

# %%
# identify if there are duplicate rows in the data
df_Clippers_complete.duplicated().sum()
# Out:
# 0

# %%
# download the two dataframes to excel files
df_Clippers_complete.to_excel('df_Clippers_complete.xlsx', index=False)
df_Clippers_EmptyOrder.to_excel('df_Clippers_EmptyOrder.xlsx', index=False)

# %% [markdown]
# #### a.	[SQL] What is the average spending for a group of 2 people?

# %%
pysqldf("""SELECT 
                avg(ProductFullPrice) as Average_spending_group_of2
            FROM df_Clippers_complete 
            WHERE GroupSize = 2""")
# Out:
#    Average_spending_group_of2
# 0                   15.357059

# %%
average = pysqldf("""SELECT 
                    avg(ProductFullPrice) 
                  FROM df_Clippers_complete 
                  WHERE GroupSize = 2""")

# %%
average
# Out:
#    avg(ProductFullPrice)
# 0              15.357059

# %%
print("The average price of ticket with group size = 2 is: USD", round(average.iloc[0,0],2))
# Out:
# The average price of ticket with group size = 2 is: USD 15.36

# %% [markdown]
# #### b.	[SQL] What was the highest amount of Food purchased in a day and what was the date (please report on ArrivalDatetime in PDT)?

# %% [markdown]
# Since pandasql runs with SQLite under the hood, I have to use the datetime function to manualy substract 7 hours from the UTC format to convert arrivaldatetime into PDT. This is not an automatization, because the time differences change from winter to summer, but is a sumplification for this problem. Note that other SQL versions (like mysql) do support timezone functions to automatize this process and prevent ourselves from errors.

# %%
pysqldf("""SELECT 
                date(datetime(ArrivalDatetime, '-7 hours')) AS pdt_time
                ,sum(productquantity) as total_quantity
            FROM df_Clippers_complete 
            WHERE Category = 'Food'
            GROUP BY pdt_time
            ORDER BY total_quantity desc
            LIMIT 1""")
# Out:
#      pdt_time  total_quantity
# 0  2023-08-26          1186.0

# %% [markdown]
# #### c.	[SQL] What were the top 5 spending orders? The result should have 4 columns: OrderID, NumOfProducts, TotalRevenue, Rank. Sort by total revenue descending.

# %%
pysqldf("""SELECT 
                OrderID
                ,sum(ProductQuantity) as NumOfProducts
                ,sum(ProductFullPrice) as TotalRevenue
                ,rank() OVER (ORDER BY sum(ProductFullPrice) desc) as Rank
            FROM df_Clippers_complete 
            GROUP BY OrderID
            ORDER BY TotalRevenue desc
            LIMIT 5
            """)
# Out:
#    OrderID  NumOfProducts  TotalRevenue  Rank
# 0    18668           14.0        282.70     1
# 1    16197           14.0        264.56     2
# 2    20940           21.0        215.21     3
# 3    26736           16.0        212.77     4
# 4    30251           10.0        200.77     5
